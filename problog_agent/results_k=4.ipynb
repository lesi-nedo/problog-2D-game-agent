# %% [markdown]
# # **Oleksiy's Problog Agent Analysis**

# %% [markdown]
# ### Libraries

# %%
from analyse import analyse, analyze_inference_and_actions

# %% [markdown]
# ### Marco's Mcts Agent vs Oleksiy's Problog Agent

# %%
# math_files = glob.glob('stats_k=4/MctsAi-vs-ProblogAgent/match-*.json')
analyse('stats_k=4/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=4/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0360 seconds
# Median Inference Time: 0.0285 seconds
# Total Actions Analyzed: 57885

# %% [markdown]
# ### FightingICE's Mcts Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=4/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 96.67%
# Loss Rate: 3.33%

# %%
analyze_inference_and_actions('stats_k=4/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0310 seconds
# Median Inference Time: 0.0246 seconds
# Total Actions Analyzed: 134575

# %% [markdown]
# ### Simone's Prolog Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=4/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=4/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0360 seconds
# Median Inference Time: 0.0286 seconds
# Total Actions Analyzed: 67684
