# %% [markdown]
# # **Oleksiy's Problog Agent Analysis**

# %% [markdown]
# ### Libraries

# %%
from analyse import analyse, analyze_inference_and_actions

# %% [markdown]
# ### Marco's Mcts Agent vs Oleksiy's Problog Agent

# %%
# math_files = glob.glob('stats_k=3/MctsAi-vs-ProblogAgent/match-*.json')
analyse('stats_k=3/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=3/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0345 seconds
# Median Inference Time: 0.0280 seconds
# Total Actions Analyzed: 60929

# %% [markdown]
# ### FightingICE's Mcts Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=3/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 98.33%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=3/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0302 seconds
# Median Inference Time: 0.0246 seconds
# Total Actions Analyzed: 132878

# %% [markdown]
# ### Simone's Prolog Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=3/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=3/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0341 seconds
# Median Inference Time: 0.0278 seconds
# Total Actions Analyzed: 73835
