# %% [markdown]
# # **Oleksiy's Problog Agent Analysis**

# %% [markdown]
# ### Libraries

# %%
from analyse import analyse, analyze_inference_and_actions

# %% [markdown]
# ### Marco's Mcts Agent vs Oleksiy's Problog Agent

# %%
# math_files = glob.glob('stats/MctsAi-vs-ProblogAgent/match-*.json')
analyse('stats_k=2/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=2/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0530 seconds
# Median Inference Time: 0.0358 seconds
# Total Actions Analyzed: 57467

# %% [markdown]
# ### FightingICE's Mcts Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=2/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 93.33%
# Loss Rate: 6.67%

# %%
analyze_inference_and_actions('stats_k=2/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0400 seconds
# Median Inference Time: 0.0297 seconds
# Total Actions Analyzed: 110264

# %% [markdown]
# ### Simone's Prolog Agent vs Oleksiy's Problog Agent

# %%
analyse('stats_k=2/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=2/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0438 seconds
# Median Inference Time: 0.0316 seconds
# Total Actions Analyzed: 76610
